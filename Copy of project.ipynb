# %%
# !git config --global user.email "priya.aashiyani139382@marwadiuniversity.ac.in"
# !git config --global user.name "P1y2a"

# %%
from getpass import getpass

token = getpass('Enter GitHub token: ')

# !git add .
# !git commit -m "valid notebook"
# !git push https://{token}@github.com/p1y2a/this-repo.git
# Out:
# Enter GitHub token: ··········
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git clone https://github.com/p1y2a/this-repo.git
# Out:
# Cloning into 'this-repo'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 17 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (17/17), 5.57 KiB | 5.57 MiB/s, done.

# %%
# %cd this-repo
# Out:
# /content/this-repo

# %%
# !cp /content/project.ipynb /content/this-repo/
# Out:
# cp: cannot stat '/content/project.ipynb': No such file or directory

# %%
# !cp /project.ipynb /content/this-repo/
# Out:
# cp: cannot stat '/project.ipynb': No such file or directory

# %%
# !cp /content/project.ipynb /content/this-repo/
